# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

sn.set()

# %%
data = pd.read_csv("Downloads/SCAMP-Cohort6-Technical-Assessment-master/SCAMP-Cohort6-Technical-Assessment-master/intermediate/fake_job_postings.csv")

# %%
data.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
plt.figure(figsize=(30, 15))
sn.barplot(data = data.groupby(by='industry').sum().reset_index(), x='industry', y='fraudulent')

# %%
grouped_data = data.groupby(by='industry').sum().reset_index()
grouped_data.loc[grouped_data['fraudulent'] == grouped_data['fraudulent'].max(),:]
# Out:
#         industry   job_id  telecommuting  has_company_logo  has_questions  \
# 88  Oil & Energy  2119613              3               232            165
#
#     fraudulent
# 88         109
